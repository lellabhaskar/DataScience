# %% [markdown]
# <a href="https://colab.research.google.com/github/lellabhaskar/DataScience/blob/main/2/1p_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Deep Learning
# Break the variables (x1,...xn) into even tinier patterns.Inputs are broken and thus mutated
# Break it again keep breaking .Make it very small -> then do pattern recognition

# if there was no patterns in smallest units, then there was no possibility of a pattern even on larger unit
# Larger patterns are built up of small patterns

# %%
# Machine Learning
y=mx+c
y=(w1,w2,w3)(x1,x2,x3) + bias =w1x1+w2x2+w3x3 + bias

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Deep Learning Equation

# %% [markdown]
# ![image.png](data:image/png;base64,...)
